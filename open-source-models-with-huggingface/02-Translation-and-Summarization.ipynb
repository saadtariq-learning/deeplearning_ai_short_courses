# %% [markdown]
# ## Setup and Import Libraries

# %%
import torch
from transformers import pipeline 
from transformers.utils import logging
logging.set_verbosity_error()

# %%
translator = pipeline(
    task="translation",
    model="facebook/nllb-200-distilled-600M",
    torch_dtype=torch.bfloat16
)

# %%
summarizer = pipeline(
    task="summarization",
    model="facebook/bart-large-cnn",
    torch_dtype=torch.bfloat16
)

# %% [markdown]
# ## Performing Translation

# %%
text = """\
My puppy is adorable, \
Your kitten is cute.
Her panda is friendly.
His llama is thoughtful. \
We all have nice pets!"""

# %%
text_translated = translator(
    text, src_lang="eng_Latn", tgt_lang="spa_Latn"
)

print(text_translated)
# Out:
# [{'translation_text': 'Mi cachorro es adorable, tu gatito es lindo, su panda es amable, su llama es atenta, todos tenemos buenas mascotas.'}]

# %%
text = """\
Mi cachorro es adorable, \
tu gatito es lindo,
su panda es amable,
su llama es atenta, \
todos tenemos buenas mascotas."""

# %%
text_translated = translator(
    text, tgt_lang="eng_Latn", src_lang="spa_Latn"
)

print(text_translated)
# Out:
# [{'translation_text': 'My puppy is adorable, your kitten is cute, his panda is kind, his flame is attentive, we all have good pets.'}]

# %% [markdown]
# ## Performing Summarization

# %%
text = """Paris is the capital and most populous city of France, with
          an estimated population of 2,175,601 residents as of 2018,
          in an area of more than 105 square kilometres (41 square
          miles). The City of Paris is the centre and seat of
          government of the region and province of Île-de-France, or
          Paris Region, which has an estimated population of
          12,174,880, or about 18 percent of the population of France
          as of 2017."""

# %%
summary = summarizer(
    text, min_length=10, max_length=100
)

print(summary)
# Out:
# [{'summary_text': 'Paris is the capital and most populous city of France, with an estimated population of 2,175,601 residents as of 2018. The City of Paris is the centre and seat of the government of the region and province of Île-de-France.'}]

# %% [markdown]
# ## Free up Memory

# %%
import gc

# %%
del translator

# %%
del summarizer

# %%
gc.collect()
# Out:
# 0
